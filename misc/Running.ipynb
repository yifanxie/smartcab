# %%
# Import the visualization code
import visuals as vs
import numpy as np
import random
import pandas as pd
import operator
# Pretty display for notebooks
# %matplotlib inline
from numpy.random import choice
import operator
import scipy

# %%
vs.plot_trials('sim_improved-learning.csv')

# %%
import pandas as pd
sim_no_learning=pd.read_csv('./logs/sim_default-learning_Q6.csv')
sim_no_learning.loc[sim_no_learning.testing==False]
# Out:
#     trial testing                             parameters  initial_deadline  \
# 0       1   False                  {'a': 0.5, 'e': 0.95}                35
# 1       2   False    {'a': 0.5, 'e': 0.8999999999999999}                20
# 2       3   False    {'a': 0.5, 'e': 0.8499999999999999}                25
# 3       4   False    {'a': 0.5, 'e': 0.7999999999999998}                25
# 4       5   False    {'a': 0.5, 'e': 0.7499999999999998}                20
# 5       6   False    {'a': 0.5, 'e': 0.6999999999999997}                20
# 6       7   False    {'a': 0.5, 'e': 0.6499999999999997}                25
# 7       8   False    {'a': 0.5, 'e': 0.5999999999999996}                25
# 8       9   False    {'a': 0.5, 'e': 0.5499999999999996}                30
# 9      10   False    {'a': 0.5, 'e': 0.4999999999999996}                25
# 10     11   False    {'a': 0.5, 'e': 0.4499999999999996}                25
# 11     12   False   {'a': 0.5, 'e': 0.39999999999999963}                20
# 12     13   False   {'a': 0.5, 'e': 0.34999999999999964}                20
# 13     14   False   {'a': 0.5, 'e': 0.29999999999999966}                25
# 14     15   False   {'a': 0.5, 'e': 0.24999999999999967}                35
# 15     16   False   {'a': 0.5, 'e': 0.19999999999999968}                20
# 16     17   False    {'a': 0.5, 'e': 0.1499999999999997}                20
# 17     18   False   {'a': 0.5, 'e': 0.09999999999999969}                20
# 18     19   False  {'a': 0.5, 'e': 0.049999999999999684}                25
# 19     20   False                {'a': 0.5, 'e': 0.0001}                35
#
#     final_deadline  net_reward                          actions  success
# 0                0 -306.236479  {0: 18, 1: 2, 2: 8, 3: 2, 4: 5}        0
# 1                0 -101.204167  {0: 12, 1: 1, 2: 5, 3: 1, 4: 1}        0
# 2                0 -171.852816  {0: 17, 1: 2, 2: 2, 3: 0, 4: 4}        0
# 3                0  -64.276408  {0: 20, 1: 0, 2: 3, 3: 1, 4: 1}        0
# 4               14    2.507719   {0: 5, 1: 1, 2: 0, 3: 0, 4: 0}        1
# 5                0  -69.043018  {0: 13, 1: 1, 2: 4, 3: 2, 4: 0}        0
# 6                0   -7.617399  {0: 21, 1: 1, 2: 3, 3: 0, 4: 0}        0
# 7                0 -114.111215  {0: 18, 1: 1, 2: 3, 3: 1, 4: 2}        0
# 8               15   -0.795899  {0: 14, 1: 0, 2: 0, 3: 1, 4: 0}        1
# 9                0 -153.300363  {0: 19, 1: 0, 2: 1, 3: 2, 4: 3}        0
# 10               0  -17.297863  {0: 20, 1: 2, 2: 3, 3: 0, 4: 0}        0
# 11               0  -28.235688  {0: 18, 1: 0, 2: 1, 3: 0, 4: 1}        0
# 12               0  -39.548315  {0: 17, 1: 0, 2: 2, 3: 0, 4: 1}        0
# 13               0  -65.216082  {0: 21, 1: 0, 2: 1, 3: 2, 4: 1}        0
# 14              16   -2.397795  {0: 16, 1: 0, 2: 3, 3: 0, 4: 0}        1
# 15              12   -9.303748   {0: 7, 1: 0, 2: 0, 3: 1, 4: 0}        1
# 16               0  -13.021390  {0: 19, 1: 0, 2: 0, 3: 0, 4: 1}        0
# 17               0   -3.883265  {0: 18, 1: 1, 2: 0, 3: 1, 4: 0}        0
# 18               0  -14.221645  {0: 24, 1: 0, 2: 0, 3: 0, 4: 1}        0
# 19               0   -6.135793  {0: 32, 1: 0, 2: 2, 3: 1, 4: 0}        0

# %%
vs.plot_trials('sim_default-learning_Q6.csv')

# %%
vs.plot_trials('sim_no-learning_Q3.csv')

# %%
epsilon=0.1
random_action = [True, False] 
weights = [epsilon, 1-epsilon]

print(choice(random_action, p=weights))
# Out:
# False

# %%
import pandas as pd
sim_no_learning=pd.read_csv('./logs/sim_no-learning.csv')
sim_no_learning.loc[sim_no_learning.testing==False]
# Out:
#     trial testing            parameters  initial_deadline  final_deadline  \
# 0       1   False  {'a': 0.5, 'e': 1.0}                25               0
# 1       2   False  {'a': 0.5, 'e': 1.0}                30               0
# 2       3   False  {'a': 0.5, 'e': 1.0}                20               0
# 3       4   False  {'a': 0.5, 'e': 1.0}                20               0
# 4       5   False  {'a': 0.5, 'e': 1.0}                30               0
# 5       6   False  {'a': 0.5, 'e': 1.0}                25               0
# 6       7   False  {'a': 0.5, 'e': 1.0}                20               0
# 7       8   False  {'a': 0.5, 'e': 1.0}                30               0
# 8       9   False  {'a': 0.5, 'e': 1.0}                20               0
# 9      10   False  {'a': 0.5, 'e': 1.0}                20               0
# 10     11   False  {'a': 0.5, 'e': 1.0}                20               0
# 11     12   False  {'a': 0.5, 'e': 1.0}                20               0
# 12     13   False  {'a': 0.5, 'e': 1.0}                25               0
# 13     14   False  {'a': 0.5, 'e': 1.0}                20               0
# 14     15   False  {'a': 0.5, 'e': 1.0}                20               0
# 15     16   False  {'a': 0.5, 'e': 1.0}                20               4
# 16     17   False  {'a': 0.5, 'e': 1.0}                20               0
# 17     18   False  {'a': 0.5, 'e': 1.0}                25               0
# 18     19   False  {'a': 0.5, 'e': 1.0}                20              11
# 19     20   False  {'a': 0.5, 'e': 1.0}                25               0
#
#     net_reward                          actions  success
# 0  -186.403226  {0: 14, 1: 2, 2: 5, 3: 1, 4: 3}        0
# 1  -102.950804  {0: 21, 1: 1, 2: 5, 3: 2, 4: 1}        0
# 2   -27.946618  {0: 16, 1: 1, 2: 2, 3: 1, 4: 0}        0
# 3  -105.281227  {0: 10, 1: 1, 2: 7, 3: 2, 4: 0}        0
# 4  -159.883585  {0: 13, 1: 6, 2: 9, 3: 1, 4: 1}        0
# 5   -38.851166  {0: 19, 1: 1, 2: 4, 3: 1, 4: 0}        0
# 6  -108.666247  {0: 14, 1: 2, 2: 1, 3: 1, 4: 2}        0
# 7  -281.397818  {0: 12, 1: 3, 2: 8, 3: 4, 4: 3}        0
# 8  -252.957540  {0: 10, 1: 1, 2: 2, 3: 2, 4: 5}        0
# 9   -71.352688  {0: 11, 1: 4, 2: 4, 3: 1, 4: 0}        0
# 10 -126.823679  {0: 11, 1: 2, 2: 3, 3: 3, 4: 1}        0
# 11  -64.502586  {0: 15, 1: 1, 2: 2, 3: 1, 4: 1}        0
# 12 -184.087989  {0: 14, 1: 2, 2: 5, 3: 1, 4: 3}        0
# 13  -18.860187  {0: 16, 1: 1, 2: 3, 3: 0, 4: 0}        0
# 14  -26.828927  {0: 14, 1: 4, 2: 2, 3: 0, 4: 0}        0
# 15  -62.630392   {0: 7, 1: 4, 2: 5, 3: 0, 4: 0}        1
# 16 -133.713100  {0: 11, 1: 1, 2: 6, 3: 0, 4: 2}        0
# 17  -70.164859  {0: 19, 1: 2, 2: 2, 3: 1, 4: 1}        0
# 18  -14.110239   {0: 6, 1: 2, 2: 1, 3: 0, 4: 0}        1
# 19 -243.903905  {0: 13, 1: 4, 2: 2, 3: 1, 4: 5}        0

# %%
reload(vs)
vs.plot_trials('sim_no-learning.csv')

# %%
reload(vs)
vs.plot_trials('sim_no-learning.csv')

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')

# %%
print(random.randint(0,2))
# Out:
# 2

# %%
3**5*24
# Out:
# 5832

# %%
a=1
b=2
c=(a,b)

# %%
type(c)
# Out:
# tuple

# %%
a='Left'
print('choose random action {}'.format(a))
# Out:
# choose random action Left

# %%
snl=pd.read_csv('./logs/sim_no-learning.csv')

# %%
snl
# Out:
#     trial testing            parameters  initial_deadline  final_deadline  \
# 0       1   False  {'a': 0.5, 'e': 1.0}                20               0
# 1       2   False  {'a': 0.5, 'e': 1.0}                30               0
# 2       3   False  {'a': 0.5, 'e': 1.0}                25               0
# 3       4   False  {'a': 0.5, 'e': 1.0}                30               0
# 4       5   False  {'a': 0.5, 'e': 1.0}                20               0
# 5       6   False  {'a': 0.5, 'e': 1.0}                30               0
# 6       7   False  {'a': 0.5, 'e': 1.0}                25              19
# 7       8   False  {'a': 0.5, 'e': 1.0}                20               0
# 8       9   False  {'a': 0.5, 'e': 1.0}                30               0
# 9      10   False  {'a': 0.5, 'e': 1.0}                25               8
# 10     11   False  {'a': 0.5, 'e': 1.0}                25               0
# 11     12   False  {'a': 0.5, 'e': 1.0}                30               0
# 12     13   False  {'a': 0.5, 'e': 1.0}                20               0
# 13     14   False  {'a': 0.5, 'e': 1.0}                25               0
# 14     15   False  {'a': 0.5, 'e': 1.0}                20               0
# 15     16   False  {'a': 0.5, 'e': 1.0}                30               8
# 16     17   False  {'a': 0.5, 'e': 1.0}                35               0
# 17     18   False  {'a': 0.5, 'e': 1.0}                20               0
# 18     19   False  {'a': 0.5, 'e': 1.0}                20               0
# 19     20   False  {'a': 0.5, 'e': 1.0}                30               0
# 20      1    True  {'a': 0.5, 'e': 1.0}                20               0
# 21      2    True  {'a': 0.5, 'e': 1.0}                30               0
# 22      3    True  {'a': 0.5, 'e': 1.0}                25               0
