# %%
# Import the visualization code
import visuals as vs
import numpy as np
import random
import pandas as pd
import operator
# Pretty display for notebooks
# %matplotlib inline

# %%
# %run ./smartcab/agent.py
# Out:
# /-------------------------
# | Training trial 1
# \-------------------------
#
# current trial is 1
# epsilon is 0.99
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 1
# choose action based on epsilon probability
# choose random action is forward
# (1, 0)
# giving reward -10.1606 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.16)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 1
# choose action based on epsilon probability
# choose random action is None
# (2, 0)
# giving reward 1.91608 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.92)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 2
# choose action based on epsilon probability
# choose random action is left
# (3, 0)
# giving reward -40.6542 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.65)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 3
# choose action based on epsilon probability
# choose random action is right
# (4, 0)
# giving reward 1.10223 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.10)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 4
# choose action based on epsilon probability
# choose random action is None
# (5, 0)
# giving reward -5.77288 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.77)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 5
# choose action based on epsilon probability
# choose random action is forward
# (6, 0)
# giving reward -9.30555 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.31)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 5
# choose action based on epsilon probability
# choose random action is right
# (7, 0)
# giving reward 0.457645 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.46)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 6
# choose action based on epsilon probability
# choose random action is right
# (8, 0)
# giving reward 1.53071 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.53)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 7
# choose action based on epsilon probability
# choose random action is right
# (9, 0)
# giving reward 1.46027 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 1.46)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 7
# choose action based on epsilon probability
# choose random action is right
# (10, 0)
# giving reward 1.67208 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.67)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 7
# choose action based on epsilon probability
# choose random action is left
# (11, 0)
# giving reward -10.5337 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.53)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 7
# choose action based on epsilon probability
# choose random action is right
# (12, 0)
# giving reward 0.999076 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.00)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 8
# choose action based on epsilon probability
# choose random action is None
# (13, 0)
# giving reward 0.976343 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 0.98)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 8
# choose action based on epsilon probability
# choose random action is right
# (14, 0)
# giving reward 1.7331 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.73)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 9
# choose action based on epsilon probability
# choose random action is forward
# (15, 0)
# giving reward -9.21176 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent attempted driving forward through a red light. (rewarded -9.21)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 10
# choose action based on epsilon probability
# choose random action is right
# (16, 0)
# giving reward 0.184183 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent drove right instead of forward. (rewarded 0.18)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 10
# choose action based on epsilon probability
# choose random action is None
# (17, 0)
# giving reward -5.9633 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.96)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 11
# choose action based on epsilon probability
# choose random action is right
# (18, 0)
# giving reward -20.8881 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -20.89)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 12
# choose action based on epsilon probability
# choose random action is right
# (19, 0)
# giving reward -20.4438 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -20.44)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is left
# (20, 0)
# giving reward 1.65049 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'right'})
# Agent followed the waypoint left. (rewarded 1.65)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 2
# \-------------------------
#
# current trial is 2
# epsilon is 0.98
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 14
# choose action based on epsilon probability
# choose random action is None
# (21, 0)
# giving reward -5.32077 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': 'left', 'left': 'left'})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.32)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 15
# choose action based on epsilon probability
# choose random action is forward
# (22, 0)
# giving reward 0.746596 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'left'})
# Agent drove forward instead of left. (rewarded 0.75)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 16
# choose action based on epsilon probability
# choose random action is None
# (23, 0)
# giving reward -5.38205 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.38)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 16
# choose action based on epsilon probability
# choose random action is forward
# (24, 0)
# giving reward 0.931587 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent drove forward instead of left. (rewarded 0.93)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 16
# choose action based on epsilon probability
# choose random action is right
# (25, 0)
# giving reward 1.44746 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.45)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 16
# choose action based on epsilon probability
# choose random action is left
# (26, 0)
# giving reward -9.46801 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.47)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 17
# choose action based on epsilon probability
# choose random action is forward
# (27, 0)
# giving reward -40.9555 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.96)
# 65% of time remaining to reach destination.
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 17
# choose action based on epsilon probability
# choose random action is right
# (28, 0)
# giving reward 2.16588 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.17)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 18
# choose action based on epsilon probability
# choose random action is right
# (29, 0)
# giving reward 1.82004 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent followed the waypoint right. (rewarded 1.82)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 19
# choose action based on epsilon probability
# choose random action is left
# (30, 0)
# giving reward -40.7864 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.79)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 20
# choose action based on epsilon probability
# choose random action is forward
# (31, 0)
# giving reward -40.8767 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'right', 'right': 'left', 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.88)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 21
# choose action based on epsilon probability
# choose random action is forward
# (32, 0)
# giving reward -10.8987 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.90)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 22
# choose action based on epsilon probability
# choose random action is left
# (33, 0)
# giving reward -10.4955 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.50)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 23
# choose action based on epsilon probability
# choose random action is right
# (34, 0)
# giving reward -0.164403 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded -0.16)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 24
# choose action based on epsilon probability
# choose random action is forward
# (35, 0)
# giving reward -39.8749 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': 'forward', 'left': None})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.87)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 25
# choose action based on epsilon probability
# choose random action is left
# (36, 0)
# giving reward -9.39347 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.39)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 26
# choose action based on epsilon probability
# choose random action is forward
# (37, 0)
# giving reward -0.534184 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove forward instead of left. (rewarded -0.53)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 26
# choose action based on epsilon probability
# choose random action is forward
# (38, 0)
# giving reward 1.1514 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove forward instead of left. (rewarded 1.15)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 27
# choose action based on epsilon probability
# choose random action is left
# (39, 0)
# giving reward 1.66766 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent followed the waypoint left. (rewarded 1.67)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 28
# choose action based on epsilon probability
# choose random action is left
# (40, 0)
# giving reward 0.0703167 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent drove left instead of forward. (rewarded 0.07)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 3
# \-------------------------
#
# current trial is 3
# epsilon is 0.97
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 29
# choose action based on epsilon probability
# choose random action is None
# (41, 0)
# giving reward 2.14312 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': 'forward', 'left': 'forward'})
# Agent properly idled at a red light. (rewarded 2.14)
# 96% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is forward
# (42, 0)
# giving reward -10.2845 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.28)
# 92% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is forward
# (43, 0)
# giving reward -39.5441 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.54)
# 88% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is forward
# (44, 0)
# giving reward -9.12782 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.13)
# 84% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 31
# choose action based on epsilon probability
# choose random action is forward
# (45, 0)
# giving reward -40.2379 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.24)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 31
# choose action based on epsilon probability
# choose random action is None
# (46, 0)
# giving reward -4.46447 to action None for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.46)
# 76% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 32
# choose action based on epsilon probability
# choose random action is forward
# (47, 0)
# giving reward 1.63516 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': 'left'})
# Agent drove forward instead of right. (rewarded 1.64)
# 72% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 33
# choose action based on epsilon probability
# choose random action is None
# (48, 0)
# giving reward -4.51032 to action None for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'right', 'right': 'forward', 'left': 'right'})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.51)
# 68% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 34
# choose action based on epsilon probability
# choose random action is right
# (49, 0)
# giving reward 1.99477 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 1.99)
# 64% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 35
# choose action based on epsilon probability
# choose random action is right
# (50, 0)
# giving reward 0.551676 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent drove right instead of forward. (rewarded 0.55)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 36
# choose action based on epsilon probability
# choose random action is forward
# (51, 0)
# giving reward 1.75605 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove forward instead of left. (rewarded 1.76)
# 56% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is right
# (52, 0)
# giving reward 0.446398 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove right instead of left. (rewarded 0.45)
# 52% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is None
# (53, 0)
# giving reward -5.65061 to action None for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.65)
# 48% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is right
# (54, 0)
# giving reward -19.3624 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -19.36)
# 44% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is left
# (55, 0)
# giving reward -39.1039 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.10)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is forward
# (56, 0)
# giving reward -10.8395 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.84)
# 36% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is forward
# (57, 0)
# giving reward -10.4457 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.45)
# 32% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is left
# (58, 0)
# giving reward 0.514195 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of right. (rewarded 0.51)
# 28% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is None
# (59, 0)
# giving reward 2.50858 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.51)
# 24% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 39
# choose action based on epsilon probability
# choose random action is None
# (60, 0)
# giving reward 0.790967 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent properly idled at a red light. (rewarded 0.79)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# number of state is 40
# choose action based on epsilon probability
# choose random action is forward
# (61, 0)
# giving reward -39.7801 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.78)
# 16% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# number of state is 41
# choose action based on epsilon probability
# choose random action is forward
# (62, 0)
# giving reward 1.16196 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent drove forward instead of left. (rewarded 1.16)
# 12% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# number of state is 42
# choose action based on epsilon probability
# choose random action is right
# (63, 0)
# giving reward 0.0974754 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': 'forward'})
# Agent drove right instead of left. (rewarded 0.10)
# 8% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# number of state is 43
# choose action based on epsilon probability
# choose random action is forward
# (64, 0)
# giving reward -9.70083 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': 'left', 'left': 'right'})
# Agent attempted driving forward through a red light. (rewarded -9.70)
# 4% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# number of state is 44
# choose action based on epsilon probability
# choose random action is forward
# (65, 0)
# giving reward -9.62921 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.63)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 4
# \-------------------------
#
# current trial is 4
# epsilon is 0.96
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is forward
# (66, 0)
# giving reward -40.5546 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.55)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is forward
# (67, 0)
# giving reward -9.5988 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent attempted driving forward through a red light. (rewarded -9.60)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is left
# (68, 0)
# giving reward -39.0941 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.09)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is forward
# (69, 0)
# giving reward -9.45923 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.46)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is forward
# (70, 0)
# giving reward -9.10515 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.11)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is None
# (71, 0)
# giving reward -4.12566 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.13)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is right
# (72, 0)
# giving reward 0.503398 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove right instead of left. (rewarded 0.50)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is None
# (73, 0)
# giving reward 1.40082 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.40)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is None
# (74, 0)
# giving reward 1.80351 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.80)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is right
# (75, 0)
# giving reward 2.34049 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.34)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 48
# choose action based on epsilon probability
# choose random action is left
# (76, 0)
# giving reward -40.3196 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.32)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 49
# choose action based on epsilon probability
# choose random action is left
# (77, 0)
# giving reward 1.67497 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent drove left instead of right. (rewarded 1.67)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose random action is forward
# (78, 0)
# giving reward 1.05904 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': None})
# Agent followed the waypoint forward. (rewarded 1.06)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 51
# choose action based on epsilon probability
# choose random action is left
# (79, 0)
# giving reward -0.33871 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'left'})
# Agent drove left instead of forward. (rewarded -0.34)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 52
# choose action based on epsilon probability
# choose random action is forward
# (80, 0)
# giving reward 1.18512 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': 'forward'})
# Agent drove forward instead of right. (rewarded 1.19)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is left
# (81, 0)
# giving reward 0.705177 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent drove left instead of right. (rewarded 0.71)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is right
# (82, 0)
# giving reward 1.06512 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent drove right instead of left. (rewarded 1.07)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is right
# (83, 0)
# giving reward 1.67649 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 1.68)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is None
# (84, 0)
# giving reward 0.698067 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 0.70)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 55
# choose action based on epsilon probability
# choose random action is None
# (85, 0)
# giving reward 0.912468 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 0.91)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 5
# \-------------------------
#
# current trial is 5
# epsilon is 0.95
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 55
# choose action based on epsilon probability
# choose random action is left
# (86, 0)
# giving reward -9.44079 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.44)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 56
# choose action based on epsilon probability
# choose random action is right
# (87, 0)
# giving reward 1.41438 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': None})
# Agent followed the waypoint right. (rewarded 1.41)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose random action is left
# (88, 0)
# giving reward -10.1951 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.20)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose action is right
# (1, 1)
# giving reward 2.25358 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.25)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose random action is right
# (89, 1)
# giving reward 1.47313 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 1.47)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose random action is forward
# (90, 1)
# giving reward -9.6416 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.64)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose random action is forward
# (91, 1)
# giving reward -9.2354 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.24)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 58
# choose action based on epsilon probability
# choose random action is right
# (92, 1)
# giving reward 0.772918 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'right', 'right': 'left', 'left': None})
# Agent drove right instead of left. (rewarded 0.77)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 59
# choose action based on epsilon probability
# choose random action is forward
# (93, 1)
# giving reward 0.165082 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove forward instead of right. (rewarded 0.17)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 60
# choose action based on epsilon probability
# choose random action is left
# (94, 1)
# giving reward -40.571 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.57)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 60
# choose action based on epsilon probability
# choose random action is forward
# (95, 1)
# giving reward -10.4728 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.47)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 61
# choose action based on epsilon probability
# choose random action is left
# (96, 1)
# giving reward 0.477951 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of forward. (rewarded 0.48)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 62
# choose action based on epsilon probability
# choose random action is left
# (97, 1)
# giving reward -9.24228 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent attempted driving left through a red light. (rewarded -9.24)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 62
# choose action based on epsilon probability
# choose random action is right
# (98, 1)
# giving reward 1.48116 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 1.48)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 62
# choose action based on epsilon probability
# choose random action is None
# (99, 1)
# giving reward -4.48724 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.49)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 63
# choose action based on epsilon probability
# choose action is right
# (2, 2)
# giving reward 1.10183 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None})
# Agent drove right instead of forward. (rewarded 1.10)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 64
# choose action based on epsilon probability
# choose random action is forward
# (100, 2)
# giving reward -10.4872 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': 'left'})
# Agent attempted driving forward through a red light. (rewarded -10.49)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is forward
# (101, 2)
# giving reward -0.0331649 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'left'})
# Agent drove forward instead of left. (rewarded -0.03)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is forward
# (102, 2)
# giving reward 0.893911 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove forward instead of left. (rewarded 0.89)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is None
# (103, 2)
# giving reward 1.73587 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.74)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 6
# \-------------------------
#
# current trial is 6
# epsilon is 0.94
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is left
# (104, 2)
# giving reward -9.18355 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.18)
# 96% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is right
# (105, 2)
# giving reward 1.53728 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.54)
# 92% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is right
# (106, 2)
# giving reward 0.448365 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 0.45)
# 88% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is left
# (107, 2)
# giving reward -10.3119 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# ...
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is None
# (998, 998)
# giving reward 1.19125 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': None})
# Agent properly idled at a red light. (rewarded 1.19)
# 16% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is forward
# (999, 999)
# giving reward 1.24214 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint forward. (rewarded 1.24)
# 12% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is None
# (1000, 1000)
# giving reward 0.597482 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent properly idled at a red light. (rewarded 0.60)
# 8% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is None
# (1001, 1001)
# giving reward 0.922868 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 0.92)
# 4% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is right
# (1002, 1002)
# giving reward -0.761002 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'right'})
# Agent drove right instead of forward. (rewarded -0.76)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Testing trial 9
# \-------------------------
#
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is None
# (1003, 1003)
# giving reward 2.99233 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': 'forward', 'left': None})
# Agent properly idled at a red light. (rewarded 2.99)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is None
# (1004, 1004)
# giving reward 2.35081 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.35)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 283
# choose action based on epsilon probability
# choose action is None
# (1005, 1005)
# giving reward 2.41265 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.41)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1006, 1006)
# giving reward 1.75487 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': 'right'})
# Agent followed the waypoint right. (rewarded 1.75)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1007, 1007)
# giving reward 2.68691 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.69)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1008, 1008)
# giving reward 2.08268 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.08)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1009, 1009)
# giving reward 1.96921 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': None})
# Agent properly idled at a red light. (rewarded 1.97)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is forward
# (1010, 1010)
# giving reward 2.20041 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent followed the waypoint forward. (rewarded 2.20)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1011, 1011)
# giving reward 2.55354 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.55)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1012, 1012)
# giving reward 0.393592 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent drove right instead of forward. (rewarded 0.39)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is left
# (1013, 1013)
# giving reward 2.35088 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint left. (rewarded 2.35)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1014, 1014)
# giving reward 1.10384 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'right'})
# Agent drove right instead of left. (rewarded 1.10)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1015, 1015)
# giving reward 2.24045 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.24)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1016, 1016)
# giving reward 0.936596 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': 'right', 'left': None})
# Agent followed the waypoint right. (rewarded 0.94)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1017, 1017)
# giving reward 0.852592 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 0.85)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1018, 1018)
# giving reward 2.22912 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent properly idled at a red light. (rewarded 2.23)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1019, 1019)
# giving reward 0.716477 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 0.72)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1020, 1020)
# giving reward 2.25805 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.26)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is right
# (1021, 1021)
# giving reward 1.78442 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent followed the waypoint right. (rewarded 1.78)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is left
# (1022, 1022)
# giving reward -39.0974 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'right', 'right': 'left', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.10)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Testing trial 10
# \-------------------------
#
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is left
# (1023, 1023)
# giving reward 1.00889 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent followed the waypoint left. (rewarded 1.01)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1024, 1024)
# giving reward 2.82799 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.83)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1025, 1025)
# giving reward 1.85547 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.86)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is None
# (1026, 1026)
# giving reward 2.12874 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': None})
# Agent properly idled at a red light. (rewarded 2.13)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is left
# (1027, 1027)
# giving reward 2.88039 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint left. (rewarded 2.88)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 284
# choose action based on epsilon probability
# choose action is left
# (1028, 1028)
# giving reward 0.980102 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent drove left instead of forward. (rewarded 0.98)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 285
# choose action based on epsilon probability
# choose action is right
# (1029, 1029)
# giving reward 1.04387 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'right', 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 1.04)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 285
# choose action based on epsilon probability
# choose action is right
# (1030, 1030)
# giving reward 2.21956 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'right', 'left': None})
# Agent followed the waypoint right. (rewarded 2.22)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 285
# choose action based on epsilon probability
# choose action is forward
# (1031, 1031)
# giving reward -40.7724 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.77)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 285
# choose action based on epsilon probability
# choose action is None
# (1032, 1032)
# giving reward 2.28863 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.29)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 285
# choose action based on epsilon probability
# choose action is None
# (1033, 1033)
# giving reward 1.03395 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.03)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 285
# choose action based on epsilon probability
# choose action is left
# (1034, 1034)
# giving reward 1.02402 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint left. (rewarded 1.02)
# 40% of time remaining to reach destination.
#
# Trial Completed!
# Agent reached the destination.
#
# Simulation ended. . .
# number of trial runs is 95
# number of states is 285
# number of random actions is 1066
# number of actions based on Q-vale is 1034

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')
print(len(agent.Q))
# Out:
# 285

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')
print(len(agent.Q))
# Out:
# 179

# %%
agent.current_trial
# Out:
# 20

# %%
agent.epsilon
# Out:
# 0

# %%
w='left'
i={'light':'red', 'oncoming': 'left', 'right': 'left', 'left':None}
s=(w,i)

# %%
s1=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
s2=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
s3=('left', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'forward'})

# %%
q={}
q[str(s1)]={}
q[str(s1)]['left']=0
q[str(s1)]['right']=0
q[str(s1)]['forward']=0
q[str(s1)]['None']=1
# q[]

# %%
max(q[str(s1)].iteritems(), key=operator.itemgetter(1))[0]
# Out:
# 'None'
