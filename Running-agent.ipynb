# %%
# Import the visualization code
import visuals as vs
import numpy as np
import random
import pandas as pd
import operator
# Pretty display for notebooks
# %matplotlib inline

# %%
# %run ./smartcab/agent.py
# Out:
# /-------------------------
# | Training trial 1
# \-------------------------
#
# current trial is 1
# epsilon is 0.95
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 1
# choose action based on epsilon probability
# choose random action is right
# (1, 0)
# giving reward 0.287288 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove right instead of left. (rewarded 0.29)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 2
# choose action based on epsilon probability
# choose random action is right
# (2, 0)
# giving reward 1.97487 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None})
# Agent followed the waypoint right. (rewarded 1.97)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 3
# choose action based on epsilon probability
# choose random action is right
# (3, 0)
# giving reward 0.856564 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'right', 'right': 'forward', 'left': 'forward'})
# Agent drove right instead of forward. (rewarded 0.86)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 4
# choose action based on epsilon probability
# choose random action is None
# (4, 0)
# giving reward 1.70048 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 1.70)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 5
# choose action based on epsilon probability
# choose random action is None
# (5, 0)
# giving reward -4.40292 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.40)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 6
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 1
# giving reward -10.8356 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.84)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 7
# choose action based on epsilon probability
# choose random action is forward
# (6, 1)
# giving reward -40.7782 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.78)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 8
# choose action based on epsilon probability
# choose random action is right
# (7, 1)
# giving reward 0.0197679 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': 'forward'})
# Agent drove right instead of left. (rewarded 0.02)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 9
# choose action based on epsilon probability
# choose random action is right
# (8, 1)
# giving reward 0.982407 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent drove right instead of left. (rewarded 0.98)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 10
# choose action based on epsilon probability
# choose random action is left
# (9, 1)
# giving reward 1.69515 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of right. (rewarded 1.70)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 11
# choose action based on epsilon probability
# choose random action is left
# (10, 1)
# giving reward -9.62352 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': 'left'})
# Agent attempted driving left through a red light. (rewarded -9.62)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 11
# choose action based on epsilon probability
# choose random action is forward
# (11, 1)
# giving reward -0.259897 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove forward instead of left. (rewarded -0.26)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 12
# choose action based on epsilon probability
# choose random action is right
# (12, 1)
# giving reward 0.648744 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'right', 'right': 'forward', 'left': None})
# Agent drove right instead of forward. (rewarded 0.65)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is None
# (13, 1)
# giving reward 1.39238 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': 'left'})
# Agent properly idled at a red light. (rewarded 1.39)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is forward
# (14, 1)
# giving reward -10.2692 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.27)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is forward
# (15, 1)
# giving reward -9.15402 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.15)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is left
# (16, 1)
# giving reward 1.19636 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint left. (rewarded 1.20)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 14
# choose action based on epsilon probability
# choose random action is left
# (17, 1)
# giving reward 0.227259 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent drove left instead of forward. (rewarded 0.23)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 15
# choose action based on epsilon probability
# choose random action is right
# (18, 1)
# giving reward 1.60023 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.60)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 16
# choose action based on epsilon probability
# choose random action is forward
# (19, 1)
# giving reward -40.8311 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': None})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.83)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 2
# \-------------------------
#
# current trial is 2
# epsilon is 0.9
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 17
# choose action based on epsilon probability
# choose random action is forward
# (20, 1)
# giving reward -9.71921 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'left'})
# Agent attempted driving forward through a red light. (rewarded -9.72)
# 97% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 18
# choose action based on epsilon probability
# choose random action is forward
# (21, 1)
# giving reward -10.2483 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.25)
# 94% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 18
# choose action based on epsilon probability
# choose random action is None
# (22, 1)
# giving reward 1.68102 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.68)
# 91% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 18
# choose action based on epsilon probability
# choose random action is left
# (23, 1)
# giving reward -9.83288 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.83)
# 89% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 18
# choose action based on epsilon probability
# choose random action is forward
# (24, 1)
# giving reward 1.11656 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove forward instead of right. (rewarded 1.12)
# 86% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 19
# choose action based on epsilon probability
# choose random action is forward
# (25, 1)
# giving reward -40.4899 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.49)
# 83% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 19
# choose action based on epsilon probability
# choose random action is right
# (26, 1)
# giving reward 1.66939 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.67)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 20
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 2
# giving reward 1.0186 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint forward. (rewarded 1.02)
# 77% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 21
# choose action based on epsilon probability
# choose random action is None
# (27, 2)
# giving reward 0.245389 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': 'right'})
# Agent idled at a green light with oncoming traffic. (rewarded 0.25)
# 74% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 22
# choose action based on epsilon probability
# choose random action is forward
# (28, 2)
# giving reward 2.55655 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent followed the waypoint forward. (rewarded 2.56)
# 71% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 22
# choose action based on epsilon probability
# choose random action is None
# (29, 2)
# giving reward -4.61202 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.61)
# 69% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 23
# choose action based on epsilon probability
# choose random action is None
# (30, 2)
# giving reward 2.26043 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.26)
# 66% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 24
# choose action based on epsilon probability
# choose random action is None
# (31, 2)
# giving reward 1.69647 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'left'})
# Agent properly idled at a red light. (rewarded 1.70)
# 63% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 25
# choose action based on epsilon probability
# choose random action is None
# (32, 2)
# giving reward 1.94876 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': 'left', 'left': None})
# Agent properly idled at a red light. (rewarded 1.95)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 26
# choose action based on epsilon probability
# choose random action is right
# (33, 2)
# giving reward 1.62875 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'right'})
# Agent drove right instead of forward. (rewarded 1.63)
# 57% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 27
# choose action based on epsilon probability
# choose random action is None
# (34, 2)
# giving reward 1.8082 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent properly idled at a red light. (rewarded 1.81)
# 54% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 28
# choose action based on epsilon probability
# choose random action is right
# (35, 2)
# giving reward -0.101273 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent drove right instead of left. (rewarded -0.10)
# 51% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 29
# choose action based on epsilon probability
# choose random action is forward
# (36, 2)
# giving reward -9.16114 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent attempted driving forward through a red light. (rewarded -9.16)
# 49% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is forward
# (37, 2)
# giving reward -9.40256 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.40)
# 46% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is right
# (38, 2)
# giving reward 1.48314 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.48)
# 43% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# number of state is 31
# choose action based on epsilon probability
# choose random action is forward
# (39, 2)
# giving reward -10.583 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.58)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# number of state is 32
# choose action based on epsilon probability
# choose random action is forward
# (40, 2)
# giving reward 0.818405 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': 'left', 'left': None})
# Agent drove forward instead of right. (rewarded 0.82)
# 37% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# number of state is 33
# choose action based on epsilon probability
# choose random action is forward
# (41, 2)
# giving reward -9.36585 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'right'})
# Agent attempted driving forward through a red light. (rewarded -9.37)
# 34% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# number of state is 34
# choose action based on epsilon probability
# choose random action is left
# (42, 2)
# giving reward -40.894 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': 'right', 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.89)
# 31% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# number of state is 35
# choose action based on epsilon probability
# choose random action is right
# (43, 2)
# giving reward -20.3779 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -20.38)
# 29% of time remaining to reach destination.
#
# /-------------------
# | Step 25 Results
# \-------------------
#
# number of state is 36
# choose action based on epsilon probability
# choose random action is right
# (44, 2)
# giving reward 2.14779 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.15)
# 26% of time remaining to reach destination.
#
# /-------------------
# | Step 26 Results
# \-------------------
#
# number of state is 36
# choose action based on epsilon probability
# choose random action is right
# (45, 2)
# giving reward -0.193704 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded -0.19)
# 23% of time remaining to reach destination.
#
# /-------------------
# | Step 27 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is forward
# (46, 2)
# giving reward -9.67658 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.68)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 28 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is None
# (47, 2)
# giving reward 1.56709 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.57)
# 17% of time remaining to reach destination.
#
# /-------------------
# | Step 29 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is None
# (48, 2)
# giving reward 1.93332 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.93)
# 14% of time remaining to reach destination.
#
# /-------------------
# | Step 30 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is forward
# (49, 2)
# giving reward -9.39645 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.40)
# 11% of time remaining to reach destination.
#
# /-------------------
# | Step 31 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is left
# (50, 2)
# giving reward 0.705413 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'right'})
# Agent followed the waypoint left. (rewarded 0.71)
# 9% of time remaining to reach destination.
#
# /-------------------
# | Step 32 Results
# \-------------------
#
# number of state is 39
# choose action based on epsilon probability
# choose random action is left
# (51, 2)
# giving reward -10.1019 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.10)
# 6% of time remaining to reach destination.
#
# /-------------------
# | Step 33 Results
# \-------------------
#
# number of state is 40
# choose action based on epsilon probability
# choose random action is left
# (52, 2)
# giving reward 0.374542 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'right', 'left': 'forward'})
# Agent followed the waypoint left. (rewarded 0.37)
# 3% of time remaining to reach destination.
#
# /-------------------
# | Step 34 Results
# \-------------------
#
# number of state is 40
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.5092983527448122, 'None': -2.3060085976869287, 'right': -0.0968521637468659, 'left': 0})
# ('max Q is:', 0.5092983527448122)
# choose action is forward
# 3
# giving reward 1.72598 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint forward. (rewarded 1.73)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 3
# \-------------------------
#
# current trial is 3
# epsilon is 0.85
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 41
# choose action based on epsilon probability
# choose random action is left
# (53, 3)
# giving reward -9.60767 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.61)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 42
# choose action based on epsilon probability
# choose random action is None
# (54, 3)
# giving reward 2.13351 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'forward'})
# Agent properly idled at a red light. (rewarded 2.13)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 43
# choose action based on epsilon probability
# choose random action is right
# (55, 3)
# giving reward 0.329583 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': 'left', 'left': None})
# Agent drove right instead of left. (rewarded 0.33)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 43
# choose action based on epsilon probability
# choose random action is left
# (56, 3)
# giving reward -10.8656 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.87)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 43
# choose action based on epsilon probability
# choose random action is left
# (57, 3)
# giving reward -10.3144 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.31)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 43
# choose action based on epsilon probability
# choose random action is left
# (58, 3)
# giving reward 1.62157 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of right. (rewarded 1.62)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 44
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 4
# giving reward -39.5533 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': 'right'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.55)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is right
# (59, 4)
# giving reward 0.50472 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent drove right instead of forward. (rewarded 0.50)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is None
# (60, 4)
# giving reward -4.53396 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'right'})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.53)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is left
# (61, 4)
# giving reward -39.9389 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'right', 'right': 'left', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.94)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 48
# choose action based on epsilon probability
# choose random action is right
# (62, 4)
# giving reward -0.116463 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'right', 'right': 'forward', 'left': None})
# Agent drove right instead of left. (rewarded -0.12)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 49
# choose action based on epsilon probability
# choose random action is left
# (63, 4)
# giving reward -9.50787 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'right'})
# Agent attempted driving left through a red light. (rewarded -9.51)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 49
# choose action based on epsilon probability
# choose random action is right
# (64, 4)
# giving reward 0.64298 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 0.64)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose random action is left
# (65, 4)
# giving reward -19.1692 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent attempted driving left through traffic and cause a minor accident. (rewarded -19.17)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 51
# choose action based on epsilon probability
# choose random action is left
# (66, 4)
# giving reward 2.12786 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None})
# Agent followed the waypoint left. (rewarded 2.13)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 52
# choose action based on epsilon probability
# choose random action is right
# (67, 4)
# giving reward 0.524947 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None})
# Agent drove right instead of forward. (rewarded 0.52)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 52
# choose action based on epsilon probability
# choose random action is left
# (68, 4)
# giving reward -9.40254 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.40)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 52
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': -7.226751203872459})
# ('max Q is:', 0)
# choose action is forward
# 5
# giving reward -10.5357 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.54)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 52
# choose action based on epsilon probability
# choose random action is right
# (69, 5)
# giving reward 0.374401 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.37)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is None
# (70, 5)
# giving reward 1.6836 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent properly idled at a red light. (rewarded 1.68)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 4
# \-------------------------
#
# current trial is 4
# epsilon is 0.8
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is right
# (71, 5)
# giving reward 0.790501 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.79)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is None
# (72, 5)
# giving reward 2.13536 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': None})
# Agent properly idled at a red light. (rewarded 2.14)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is forward
# (73, 5)
# giving reward -10.7803 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.78)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is left
# (74, 5)
# giving reward -10.7277 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.73)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is left
# (75, 5)
# giving reward -9.08891 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.09)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose random action is None
# (76, 5)
# giving reward 1.33576 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.34)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is right
# (77, 5)
# giving reward 1.53484 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent followed the waypoint right. (rewarded 1.53)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 55
# choose action based on epsilon probability
# choose random action is left
# (78, 5)
# giving reward -9.15313 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.15)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 56
# choose action based on epsilon probability
# choose random action is right
# (79, 5)
# giving reward 0.500161 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': 'right', 'left': None})
# Agent drove right instead of forward. (rewarded 0.50)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose random action is left
# (80, 5)
# giving reward 1.00027 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent followed the waypoint left. (rewarded 1.00)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 58
# choose action based on epsilon probability
# choose random action is right
# (81, 5)
# giving reward 1.79317 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent followed the waypoint right. (rewarded 1.79)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 59
# choose action based on epsilon probability
# choose random action is None
# (82, 5)
# giving reward 1.29875 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 1.30)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 59
# choose action based on epsilon probability
# choose random action is left
# (83, 5)
# giving reward -0.127419 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove left instead of forward. (rewarded -0.13)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 60
# choose action based on epsilon probability
# choose random action is forward
# (84, 5)
# giving reward -39.5165 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.52)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 60
# choose action based on epsilon probability
# choose random action is None
# (85, 5)
# giving reward 0.753041 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': None})
# Agent properly idled at a red light. (rewarded 0.75)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 61
# choose action based on epsilon probability
# choose random action is right
# (86, 5)
# giving reward -20.5401 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -20.54)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 62
# choose action based on epsilon probability
# choose random action is left
# (87, 5)
# giving reward -10.8653 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'left'})
# Agent attempted driving left through a red light. (rewarded -10.87)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 63
# choose action based on epsilon probability
# choose random action is left
# (88, 5)
# giving reward -20.2268 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': 'left'})
# Agent attempted driving left through traffic and cause a minor accident. (rewarded -20.23)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 64
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 6
# giving reward -0.700518 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent drove forward instead of right. (rewarded -0.70)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 64
# choose action based on epsilon probability
# choose random action is None
# (89, 6)
# giving reward 0.692891 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 0.69)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 5
# \-------------------------
#
# current trial is 5
# epsilon is 0.75
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 7
# giving reward -39.4944 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.49)
# 97% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 66
# choose action based on epsilon probability
# choose random action is forward
# (90, 7)
# giving reward -10.5452 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.55)
# 93% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 67
# choose action based on epsilon probability
# choose random action is None
# (91, 7)
# giving reward 1.80528 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.81)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 67
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0.8001149858483081, 'left': 0})
# ('max Q is:', 0.8001149858483081)
# choose action is right
# 8
# giving reward 1.67632 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.68)
# 87% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 67
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.5582775944368561, 'None': 0, 'right': 0.7415720959209581, 'left': 1.234573240674206})
# ('max Q is:', 1.234573240674206)
# choose action is left
# 9
# giving reward 0.390125 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of right. (rewarded 0.39)
# 83% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 67
# choose action based on epsilon probability
# choose random action is forward
# (92, 9)
# giving reward 2.07072 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint forward. (rewarded 2.07)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 67
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 1.130213399512188, 'right': 0.3214897858786211, 'left': 0})
# ('max Q is:', 1.130213399512188)
# choose action is None
# 10
# giving reward 1.55731 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.56)
# 77% of time remaining to reach destination.
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 68
# choose action based on epsilon probability
# choose random action is left
# (93, 10)
# giving reward -39.1567 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.16)
# 73% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 69
# choose action based on epsilon probability
# choose random action is None
# (94, 10)
# giving reward 1.91092 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': 'left'})
# Agent properly idled at a red light. (rewarded 1.91)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 69
# choose action based on epsilon probability
# choose random action is forward
# (95, 10)
# giving reward 1.58839 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent followed the waypoint forward. (rewarded 1.59)
# 67% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 69
# choose action based on epsilon probability
# choose random action is left
# (96, 10)
# giving reward 1.43138 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of forward. (rewarded 1.43)
# 63% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 70
# choose action based on epsilon probability
# choose random action is right
# (97, 10)
# giving reward 1.68142 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent followed the waypoint right. (rewarded 1.68)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 70
# choose action based on epsilon probability
# ...
# ('max Q is:', 0)
# choose action is forward
# 386
# giving reward -40.2801 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.28)
# 84% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': -5.159046303421507, 'None': 0.0, 'right': 0, 'left': 0})
# ('max Q is:', 0.0)
# choose action is None
# 387
# giving reward 2.3868 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent properly idled at a red light. (rewarded 2.39)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0.8148295158949141, 'right': 0, 'left': 0.013337413571581525})
# ('max Q is:', 0.8148295158949141)
# choose action is None
# 388
# giving reward 0.386068 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 0.39)
# 76% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0.8148295158949141, 'right': 0, 'left': 0.013337413571581525})
# ('max Q is:', 0.8148295158949141)
# choose action is None
# 389
# giving reward 1.02803 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 1.03)
# 72% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 1.2745968175003966, 'None': -3.312420478538482, 'right': -0.21167471989854503, 'left': 0.7156922722622208})
# ('max Q is:', 1.2745968175003966)
# choose action is forward
# 390
# giving reward 2.06028 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint forward. (rewarded 2.06)
# 68% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.5922944631823843, 'None': -2.07332147066426, 'right': 0, 'left': 0})
# ('max Q is:', 0.5922944631823843)
# choose action is forward
# 391
# giving reward 1.58046 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent drove forward instead of right. (rewarded 1.58)
# 64% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 1.7585307229208453, 'left': 0})
# ('max Q is:', 1.7585307229208453)
# choose action is right
# 392
# giving reward 1.70937 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.71)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': -7.0882865556344425, 'None': 1.914903661031229, 'right': 0.6124495353214885, 'left': 0})
# ('max Q is:', 1.914903661031229)
# choose action is None
# 393
# giving reward 2.5451 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent properly idled at a red light. (rewarded 2.55)
# 56% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.0, 'None': 0, 'right': 0, 'left': -5.366050894189269})
# ('max Q is:', 0.0)
# choose action is forward
# 394
# giving reward -10.5957 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.60)
# 52% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0.9026421760824247, 'right': 1.1827548754674706, 'left': 0})
# ('max Q is:', 1.1827548754674706)
# choose action is right
# 395
# giving reward 2.1368 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.14)
# 48% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 1.5441041111006326})
# ('max Q is:', 1.5441041111006326)
# choose action is left
# 396
# giving reward 2.16836 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent followed the waypoint left. (rewarded 2.17)
# 44% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0.7149980932377901})
# ('max Q is:', 0.7149980932377901)
# choose action is left
# 397
# giving reward 1.57633 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent drove left instead of forward. (rewarded 1.58)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': -5.291479318153154, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is None
# 398
# giving reward 1.20653 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.21)
# 36% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.6460771914036987, 'None': 0, 'right': 1.8856072590414845, 'left': 0})
# ('max Q is:', 1.8856072590414845)
# choose action is right
# 399
# giving reward 1.94189 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.94)
# 32% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 172
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 1.7585307229208453, 'left': 0})
# ('max Q is:', 1.7585307229208453)
# choose action is right
# 400
# giving reward 1.65864 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.66)
# 28% of time remaining to reach destination.
#
# Trial Completed!
# Agent reached the destination.
#
# /-------------------------
# | Testing trial 10
# \-------------------------
#
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 401
# giving reward 0.828363 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': 'left', 'left': 'left'})
# Agent drove forward instead of right. (rewarded 0.83)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 1.8743872033745244, 'left': 0})
# ('max Q is:', 1.8743872033745244)
# choose action is right
# 402
# giving reward 2.41632 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent followed the waypoint right. (rewarded 2.42)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': 1.21155141939723, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 1.21155141939723)
# choose action is forward
# 403
# giving reward 1.17608 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent followed the waypoint forward. (rewarded 1.18)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': -4.657783058235172, 'None': 1.1752496202782314, 'right': 0, 'left': -4.803833795001201})
# ('max Q is:', 1.1752496202782314)
# choose action is None
# 404
# giving reward 1.58366 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.58)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': -4.657783058235172, 'None': 1.1752496202782314, 'right': 0, 'left': -4.803833795001201})
# ('max Q is:', 1.1752496202782314)
# choose action is None
# 405
# giving reward 2.21272 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.21)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.22921572952375635, 'None': -2.3940512532109377, 'right': 0, 'left': -9.584606827897549})
# ('max Q is:', 0.22921572952375635)
# choose action is forward
# 406
# giving reward 1.14619 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove forward instead of left. (rewarded 1.15)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': -9.365376831758567, 'None': 0, 'right': 0.35054780012525305, 'left': -10.199931709804659})
# ('max Q is:', 0.35054780012525305)
# choose action is right
# 407
# giving reward 0.909937 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.91)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': -2.161430424676449, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 408
# giving reward 0.542217 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'left'})
# Agent drove forward instead of right. (rewarded 0.54)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': -4.66794249873776, 'None': 1.9438562847509395, 'right': 0, 'left': 0})
# ('max Q is:', 1.9438562847509395)
# choose action is None
# 409
# giving reward 1.8811 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.88)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 173
# choose action based on epsilon probability
# ('state Q values are', {'forward': -4.66794249873776, 'None': 1.9438562847509395, 'right': 0, 'left': 0})
# ('max Q is:', 1.9438562847509395)
# choose action is None
# 410
# giving reward 1.12278 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.12)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 174
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 411
# giving reward 0.75318 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': 'forward'})
# Agent drove forward instead of right. (rewarded 0.75)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 175
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0, 'None': 0, 'right': 0, 'left': 0})
# ('max Q is:', 0)
# choose action is forward
# 412
# giving reward 1.48708 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'forward'})
# Agent drove forward instead of right. (rewarded 1.49)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 175
# choose action based on epsilon probability
# ('state Q values are', {'forward': -8.542731829021774, 'None': 1.1317830963819697, 'right': 1.3885243332690407, 'left': -9.367795548222261})
# ('max Q is:', 1.3885243332690407)
# choose action is right
# 413
# giving reward 1.69007 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.69)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 175
# choose action based on epsilon probability
# ('state Q values are', {'forward': 0.5582775944368561, 'None': 0, 'right': 1.411583387339098, 'left': 0.03346600657555443})
# ('max Q is:', 1.411583387339098)
# choose action is right
# 414
# giving reward 2.1065 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.11)
# 30% of time remaining to reach destination.
#
# Trial Completed!
# Agent reached the destination.
#
# Simulation ended. . .
# number of trial runs is 20
# number of states is 175
# number of random actions is 207
# number of actions based on Q-value is 414

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')
print(len(agent.Q))
# Out:
# 176

# %%
reload(vs)
vs.plot_trials('sim_improved-learning.csv')
print(len(agent.Q))
# Out:
# 384

# %%
reload(vs)
vs.plot_trials('sim_no-learning.csv')
# print(len(agent.Q))

# %%
reload(vs)
vs.plot_trials('sim_improved-learning.csv')
print(len(agent.Q))
# Out:
# 186

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')
print(len(agent.Q))
# Out:
# 179

# %%
agent.current_trial
# Out:
# 20

# %%
agent.epsilon
# Out:
# 0

# %%
w='left'
i={'light':'red', 'oncoming': 'left', 'right': 'left', 'left':None}
s=(w,i)

# %%
s1=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
s2=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
s3=('left', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'forward'})

# %%
q={}
q[str(s1)]={}
q[str(s1)]['left']=0
q[str(s1)]['right']=0
q[str(s1)]['forward']=0
q[str(s1)]['None']=1
# q[]

# %%
max(q[str(s1)].iteritems(), key=operator.itemgetter(1))[0]
# Out:
# 'None'
