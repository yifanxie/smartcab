# %%
# Import the visualization code
import visuals as vs
import numpy as np
import random
import pandas as pd
import operator
# Pretty display for notebooks
# %matplotlib inline

# %%
# %run ./smartcab/agent.py
# Out:
# /-------------------------
# | Training trial 1
# \-------------------------
#
# current trial is 1
# epsilon is 0.95
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 1
# choose action based on epsilon probability
# choose random action is left
# (1, 0)
# giving reward -39.492 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.49)
# 97% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 2
# choose action based on epsilon probability
# choose random action is left
# (2, 0)
# giving reward -39.7637 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'right'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.76)
# 94% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 3
# choose action based on epsilon probability
# choose random action is None
# (3, 0)
# giving reward 1.31149 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.31)
# 91% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 4
# choose action based on epsilon probability
# choose random action is right
# (4, 0)
# giving reward 1.69797 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None})
# Agent followed the waypoint right. (rewarded 1.70)
# 89% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 5
# choose action based on epsilon probability
# choose random action is left
# (5, 0)
# giving reward -39.5191 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.52)
# 86% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 6
# choose action based on epsilon probability
# choose random action is left
# (6, 0)
# giving reward -9.48246 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.48)
# 83% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 7
# choose action based on epsilon probability
# choose random action is left
# (7, 0)
# giving reward -9.47975 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent attempted driving left through a red light. (rewarded -9.48)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 8
# choose action based on epsilon probability
# choose action is right
# (1, 1)
# giving reward 0.642918 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': None})
# Agent drove right instead of forward. (rewarded 0.64)
# 77% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 9
# choose action based on epsilon probability
# choose action is right
# (2, 2)
# giving reward -0.0547893 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded -0.05)
# 74% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 10
# choose action based on epsilon probability
# choose random action is left
# (8, 2)
# giving reward 1.57421 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint left. (rewarded 1.57)
# 71% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 10
# choose action based on epsilon probability
# choose random action is right
# (9, 2)
# giving reward 1.59077 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.59)
# 69% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 11
# choose action based on epsilon probability
# choose random action is right
# (10, 2)
# giving reward -20.6026 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -20.60)
# 66% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 12
# choose action based on epsilon probability
# choose random action is None
# (11, 2)
# giving reward 2.80542 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'forward'})
# Agent properly idled at a red light. (rewarded 2.81)
# 63% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is right
# (12, 2)
# giving reward 1.19383 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 1.19)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 13
# choose action based on epsilon probability
# choose random action is right
# (13, 2)
# giving reward 0.643509 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.64)
# 57% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 14
# choose action based on epsilon probability
# choose random action is left
# (14, 2)
# giving reward -9.75889 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': 'left'})
# Agent attempted driving left through a red light. (rewarded -9.76)
# 54% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 15
# choose action based on epsilon probability
# choose random action is right
# (15, 2)
# giving reward 0.0850674 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 0.09)
# 51% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 16
# choose action based on epsilon probability
# choose random action is left
# (16, 2)
# giving reward 1.78473 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent followed the waypoint left. (rewarded 1.78)
# 49% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 17
# choose action based on epsilon probability
# choose random action is right
# (17, 2)
# giving reward 0.582638 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent drove right instead of forward. (rewarded 0.58)
# 46% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 18
# choose action based on epsilon probability
# choose random action is left
# (18, 2)
# giving reward -40.5816 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.58)
# 43% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# number of state is 19
# choose action based on epsilon probability
# choose random action is forward
# (19, 2)
# giving reward -9.10686 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'right', 'right': 'right', 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.11)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# number of state is 20
# choose action based on epsilon probability
# choose random action is None
# (20, 2)
# giving reward 0.877349 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 0.88)
# 37% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# number of state is 21
# choose action based on epsilon probability
# choose random action is forward
# (21, 2)
# giving reward 1.47076 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent drove forward instead of left. (rewarded 1.47)
# 34% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# number of state is 22
# choose action based on epsilon probability
# choose random action is right
# (22, 2)
# giving reward -20.0106 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -20.01)
# 31% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# number of state is 23
# choose action based on epsilon probability
# choose random action is left
# (23, 2)
# giving reward -9.01401 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.01)
# 29% of time remaining to reach destination.
#
# /-------------------
# | Step 25 Results
# \-------------------
#
# number of state is 23
# choose action based on epsilon probability
# choose random action is left
# (24, 2)
# giving reward -9.89985 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.90)
# 26% of time remaining to reach destination.
#
# /-------------------
# | Step 26 Results
# \-------------------
#
# number of state is 24
# choose action based on epsilon probability
# choose random action is left
# (25, 2)
# giving reward 1.23704 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint left. (rewarded 1.24)
# 23% of time remaining to reach destination.
#
# /-------------------
# | Step 27 Results
# \-------------------
#
# number of state is 25
# choose action based on epsilon probability
# choose random action is forward
# (26, 2)
# giving reward 1.48394 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent followed the waypoint forward. (rewarded 1.48)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 28 Results
# \-------------------
#
# number of state is 25
# choose action based on epsilon probability
# choose random action is None
# (27, 2)
# giving reward -5.23122 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.23)
# 17% of time remaining to reach destination.
#
# /-------------------
# | Step 29 Results
# \-------------------
#
# number of state is 26
# choose action based on epsilon probability
# choose random action is left
# (28, 2)
# giving reward -39.5783 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.58)
# 14% of time remaining to reach destination.
#
# /-------------------
# | Step 30 Results
# \-------------------
#
# number of state is 26
# choose action based on epsilon probability
# choose random action is forward
# (29, 2)
# giving reward -9.31011 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.31)
# 11% of time remaining to reach destination.
#
# /-------------------
# | Step 31 Results
# \-------------------
#
# number of state is 26
# choose action based on epsilon probability
# choose random action is right
# (30, 2)
# giving reward -0.0337298 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded -0.03)
# 9% of time remaining to reach destination.
#
# /-------------------
# | Step 32 Results
# \-------------------
#
# number of state is 27
# choose action based on epsilon probability
# choose random action is left
# (31, 2)
# giving reward -10.8591 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.86)
# 6% of time remaining to reach destination.
#
# /-------------------
# | Step 33 Results
# \-------------------
#
# number of state is 27
# choose action based on epsilon probability
# choose random action is left
# (32, 2)
# giving reward 2.04361 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint left. (rewarded 2.04)
# 3% of time remaining to reach destination.
#
# /-------------------
# | Step 34 Results
# \-------------------
#
# number of state is 28
# choose action based on epsilon probability
# choose random action is None
# (33, 2)
# giving reward -5.48304 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': 'left', 'left': 'forward'})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.48)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 2
# \-------------------------
#
# current trial is 2
# epsilon is 0.9
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 29
# choose action based on epsilon probability
# choose random action is right
# (34, 2)
# giving reward 0.728196 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'left'})
# Agent drove right instead of left. (rewarded 0.73)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is forward
# (35, 2)
# giving reward -10.5184 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.52)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 30
# choose action based on epsilon probability
# choose random action is left
# (36, 2)
# giving reward -10.6259 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.63)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 31
# choose action based on epsilon probability
# choose random action is forward
# (37, 2)
# giving reward 1.0177 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': 'left'})
# Agent drove forward instead of right. (rewarded 1.02)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 32
# choose action based on epsilon probability
# choose random action is forward
# (38, 2)
# giving reward 1.04872 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent followed the waypoint forward. (rewarded 1.05)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 33
# choose action based on epsilon probability
# choose random action is right
# (39, 2)
# giving reward -19.9265 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -19.93)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 33
# choose action based on epsilon probability
# choose random action is forward
# (40, 2)
# giving reward -39.0298 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.03)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 33
# choose action based on epsilon probability
# choose random action is left
# (41, 2)
# giving reward -9.49913 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.50)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 33
# choose action based on epsilon probability
# choose random action is forward
# (42, 2)
# giving reward -9.13927 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.14)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 34
# choose action based on epsilon probability
# choose random action is right
# (43, 2)
# giving reward 0.449363 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'right', 'left': None})
# Agent drove right instead of forward. (rewarded 0.45)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 34
# choose action based on epsilon probability
# choose random action is None
# (44, 2)
# giving reward 1.49546 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.50)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 35
# choose action based on epsilon probability
# choose random action is forward
# (45, 2)
# giving reward 0.719056 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': None})
# Agent drove forward instead of left. (rewarded 0.72)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 36
# choose action based on epsilon probability
# choose random action is right
# (46, 2)
# giving reward 1.17174 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': 'left', 'left': None})
# Agent drove right instead of left. (rewarded 1.17)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 37
# choose action based on epsilon probability
# choose random action is right
# (47, 2)
# giving reward 1.94289 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.94)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is None
# (48, 2)
# giving reward -5.44156 to action None for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.44)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 38
# choose action based on epsilon probability
# choose random action is right
# (49, 2)
# giving reward 2.27224 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 2.27)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 39
# choose action based on epsilon probability
# choose random action is right
# (50, 2)
# giving reward 1.07757 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'right', 'right': 'left', 'left': 'left'})
# Agent drove right instead of forward. (rewarded 1.08)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 40
# choose action based on epsilon probability
# choose action is right
# (3, 3)
# giving reward 0.597206 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent drove right instead of left. (rewarded 0.60)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 40
# choose action based on epsilon probability
# choose random action is forward
# (51, 3)
# giving reward 0.309265 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove forward instead of right. (rewarded 0.31)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 40
# choose action based on epsilon probability
# choose random action is forward
# (52, 3)
# giving reward -9.85295 to action forward for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.85)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 3
# \-------------------------
#
# current trial is 3
# epsilon is 0.85
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 41
# choose action based on epsilon probability
# choose action is right
# (4, 4)
# giving reward 0.558139 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent drove right instead of left. (rewarded 0.56)
# 96% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 41
# choose action based on epsilon probability
# choose random action is forward
# (53, 4)
# giving reward 1.09147 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove forward instead of right. (rewarded 1.09)
# 92% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 42
# choose action based on epsilon probability
# choose action is right
# (5, 5)
# giving reward 1.20222 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent followed the waypoint right. (rewarded 1.20)
# 88% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 42
# choose action based on epsilon probability
# choose random action is right
# (54, 5)
# giving reward 0.48967 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 0.49)
# 84% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 42
# choose action based on epsilon probability
# choose action is None
# (6, 6)
# giving reward 0.402017 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 0.40)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 43
# choose action based on epsilon probability
# choose random action is None
# (55, 6)
# giving reward -4.4162 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent idled at a green light with no oncoming traffic. (rewarded -4.42)
# 76% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 44
# choose action based on epsilon probability
# choose random action is left
# (56, 6)
# giving reward -39.535 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.53)
# 72% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 44
# choose action based on epsilon probability
# choose random action is forward
# (57, 6)
# giving reward -9.81877 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -9.82)
# 68% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is None
# (58, 6)
# giving reward 1.70905 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent properly idled at a red light. (rewarded 1.71)
# 64% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is left
# (59, 6)
# giving reward -10.8189 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.82)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is None
# (60, 6)
# giving reward 1.88433 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.88)
# 56% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 45
# choose action based on epsilon probability
# choose random action is left
# (61, 6)
# giving reward 1.55453 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint left. (rewarded 1.55)
# 52% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is right
# (62, 6)
# giving reward 0.394535 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent drove right instead of forward. (rewarded 0.39)
# 48% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is left
# (63, 6)
# giving reward -39.85 to action left for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.85)
# 44% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is None
# (64, 6)
# giving reward 2.57019 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.57)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose action is None
# (7, 7)
# giving reward 2.38844 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.39)
# 36% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is right
# (65, 7)
# giving reward 1.29714 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent drove right instead of left. (rewarded 1.30)
# 32% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 46
# choose action based on epsilon probability
# choose random action is right
# (66, 7)
# giving reward 1.53188 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.53)
# 28% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 47
# choose action based on epsilon probability
# choose random action is right
# (67, 7)
# giving reward 1.10632 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': 'left', 'left': 'left'})
# Agent followed the waypoint right. (rewarded 1.11)
# 24% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 48
# choose action based on epsilon probability
# choose random action is right
# (68, 7)
# giving reward -0.192359 to action right for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent drove right instead of forward. (rewarded -0.19)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# number of state is 48
# choose action based on epsilon probability
# choose random action is None
# (69, 7)
# giving reward -5.40812 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.41)
# 16% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# number of state is 48
# choose action based on epsilon probability
# choose random action is forward
# (70, 7)
# giving reward -40.8546 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.85)
# 12% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# number of state is 48
# choose action based on epsilon probability
# choose random action is forward
# (71, 7)
# giving reward -39.6127 to action forward for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -39.61)
# 8% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# number of state is 49
# choose action based on epsilon probability
# choose random action is right
# (72, 7)
# giving reward 1.07779 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.08)
# 4% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose random action is right
# (73, 7)
# giving reward -0.603883 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent drove right instead of left. (rewarded -0.60)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 4
# \-------------------------
#
# current trial is 4
# epsilon is 0.8
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose random action is right
# (74, 7)
# giving reward 1.27005 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.27)
# 96% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose action is forward
# (8, 8)
# giving reward 2.49073 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent followed the waypoint forward. (rewarded 2.49)
# 92% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose random action is None
# (75, 8)
# giving reward 1.40749 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.41)
# 88% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose action is None
# (9, 9)
# giving reward 2.72594 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.73)
# 84% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose action is None
# (10, 10)
# giving reward 1.05563 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.06)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 50
# choose action based on epsilon probability
# choose random action is left
# (76, 10)
# giving reward -9.93028 to action left for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -9.93)
# 76% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 51
# choose action based on epsilon probability
# choose random action is None
# (77, 10)
# giving reward 0.859129 to action None for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent idled at a green light with oncoming traffic. (rewarded 0.86)
# 72% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 52
# choose action based on epsilon probability
# choose random action is right
# (78, 10)
# giving reward 0.975601 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'right'})
# Agent drove right instead of forward. (rewarded 0.98)
# 68% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose action is right
# (11, 11)
# giving reward -19.832 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -19.83)
# 64% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 53
# choose action based on epsilon probability
# choose action is right
# (12, 12)
# giving reward 1.64985 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.65)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is right
# (79, 12)
# giving reward 2.04031 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.04)
# 56% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is left
# (80, 12)
# giving reward -10.3791 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving left through a red light. (rewarded -10.38)
# 52% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is None
# (81, 12)
# giving reward 1.45162 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.45)
# 48% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 54
# choose action based on epsilon probability
# choose random action is forward
# (82, 12)
# giving reward 1.48512 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove forward instead of right. (rewarded 1.49)
# 44% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 55
# choose action based on epsilon probability
# choose action is right
# (13, 13)
# giving reward 0.974923 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'forward'})
# Agent followed the waypoint right. (rewarded 0.97)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 56
# choose action based on epsilon probability
# choose random action is forward
# (83, 13)
# giving reward 2.58461 to action forward for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent followed the waypoint forward. (rewarded 2.58)
# 36% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 56
# choose action based on epsilon probability
# choose random action is right
# (84, 13)
# giving reward 0.445187 to action right for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.45)
# 32% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 57
# choose action based on epsilon probability
# choose random action is left
# (85, 13)
# giving reward -40.8266 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'right', 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.83)
# 28% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 58
# choose action based on epsilon probability
# choose random action is None
# (86, 13)
# giving reward 0.540372 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'left'})
# Agent properly idled at a red light. (rewarded 0.54)
# 24% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 58
# choose action based on epsilon probability
# choose random action is left
# (87, 13)
# giving reward 1.05675 to action left for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove left instead of right. (rewarded 1.06)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# number of state is 59
# choose action based on epsilon probability
# choose random action is right
# (88, 13)
# giving reward 0.7486 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'right', 'left': None})
# Agent drove right instead of left. (rewarded 0.75)
# 16% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# number of state is 59
# choose action based on epsilon probability
# choose random action is forward
# (89, 13)
# giving reward 0.39714 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None})
# Agent drove forward instead of right. (rewarded 0.40)
# 12% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# number of state is 60
# choose action based on epsilon probability
# choose random action is None
# (90, 13)
# giving reward 1.65944 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent properly idled at a red light. (rewarded 1.66)
# 8% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# number of state is 61
# choose action based on epsilon probability
# choose random action is None
# (91, 13)
# giving reward 0.944796 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': 'right', 'left': None})
# Agent properly idled at a red light. (rewarded 0.94)
# 4% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# number of state is 61
# choose action based on epsilon probability
# choose random action is forward
# (92, 13)
# giving reward -10.0717 to action forward for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent attempted driving forward through a red light. (rewarded -10.07)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 5
# \-------------------------
#
# current trial is 5
# epsilon is 0.75
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 62
# choose action based on epsilon probability
# choose action is right
# (14, 14)
# giving reward 1.7909 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'left'})
# Agent followed the waypoint right. (rewarded 1.79)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 63
# choose action based on epsilon probability
# choose random action is right
# (93, 14)
# giving reward 0.464183 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': None})
# Agent drove right instead of forward. (rewarded 0.46)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 64
# choose action based on epsilon probability
# choose random action is forward
# (94, 14)
# giving reward 1.92612 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': 'forward'})
# Agent drove forward instead of left. (rewarded 1.93)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 64
# choose action based on epsilon probability
# choose action is None
# (15, 15)
# giving reward 2.54756 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.55)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 65
# choose action based on epsilon probability
# choose random action is None
# (95, 15)
# giving reward -5.8758 to action None for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'right', 'left': 'forward'})
# Agent idled at a green light with no oncoming traffic. (rewarded -5.88)
# ...
# Agent properly idled at a red light. (rewarded 2.71)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (432, 432)
# giving reward 1.18143 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.18)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (433, 433)
# giving reward 1.04566 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.05)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (434, 434)
# giving reward 1.31563 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.32)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (435, 435)
# giving reward 1.18401 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.18)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (436, 436)
# giving reward 2.72974 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'left'})
# Agent followed the waypoint right. (rewarded 2.73)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (437, 437)
# giving reward 1.12175 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.12)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (438, 438)
# giving reward 1.53841 to action None for current state
# Agent previous state: ('forward', {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.54)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (439, 439)
# giving reward -0.0219443 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'forward'})
# Agent drove right instead of forward. (rewarded -0.02)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (440, 440)
# giving reward 2.68269 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.68)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (441, 441)
# giving reward 1.86797 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.87)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is left
# (442, 442)
# giving reward 1.47219 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent followed the waypoint left. (rewarded 1.47)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (443, 443)
# giving reward 1.29509 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': None})
# Agent drove right instead of forward. (rewarded 1.30)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (444, 444)
# giving reward 2.07552 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.08)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is left
# (445, 445)
# giving reward 1.89508 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'})
# Agent followed the waypoint left. (rewarded 1.90)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (446, 446)
# giving reward 1.16172 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 1.16)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (447, 447)
# giving reward 1.19269 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'right'})
# Agent drove right instead of forward. (rewarded 1.19)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is None
# (448, 448)
# giving reward 1.72379 to action None for current state
# Agent previous state: ('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.72)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Testing trial 10
# \-------------------------
#
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is right
# (449, 449)
# giving reward 1.30993 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': None, 'right': 'right', 'left': None})
# Agent followed the waypoint right. (rewarded 1.31)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# number of state is 179
# choose action based on epsilon probability
# choose action is left
# (450, 450)
# giving reward 1.72441 to action left for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'forward'})
# Agent drove left instead of forward. (rewarded 1.72)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# number of state is 180
# choose action based on epsilon probability
# choose action is right
# (451, 451)
# giving reward 2.00333 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'right'})
# Agent followed the waypoint right. (rewarded 2.00)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# number of state is 180
# choose action based on epsilon probability
# choose action is right
# (452, 452)
# giving reward 1.79603 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 1.80)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# number of state is 180
# choose action based on epsilon probability
# choose action is None
# (453, 453)
# giving reward 1.4853 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.49)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# number of state is 181
# choose action based on epsilon probability
# choose action is right
# (454, 454)
# giving reward 2.57757 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 2.58)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is right
# (455, 455)
# giving reward 2.19948 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': 'left'})
# Agent followed the waypoint right. (rewarded 2.20)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is right
# (456, 456)
# giving reward 2.42187 to action right for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': None})
# Agent followed the waypoint right. (rewarded 2.42)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is forward
# (457, 457)
# giving reward 1.11256 to action forward for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent drove forward instead of left. (rewarded 1.11)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is right
# (458, 458)
# giving reward 0.303824 to action right for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove right instead of left. (rewarded 0.30)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is None
# (459, 459)
# giving reward 2.57334 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 2.57)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is right
# (460, 460)
# giving reward -19.4013 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
# Agent attempted driving right through traffic and cause a minor accident. (rewarded -19.40)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is left
# (461, 461)
# giving reward -40.457 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.46)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is forward
# (462, 462)
# giving reward 1.01728 to action forward for current state
# Agent previous state: ('right', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})
# Agent drove forward instead of right. (rewarded 1.02)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is None
# (463, 463)
# giving reward 1.37771 to action None for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
# Agent properly idled at a red light. (rewarded 1.38)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is right
# (464, 464)
# giving reward 2.33883 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': None})
# Agent followed the waypoint right. (rewarded 2.34)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is left
# (465, 465)
# giving reward -39.2126 to action left for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'forward'})
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.21)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# number of state is 182
# choose action based on epsilon probability
# choose action is right
# (466, 466)
# giving reward 1.87268 to action right for current state
# Agent previous state: ('right', {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'right'})
# Agent followed the waypoint right. (rewarded 1.87)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# number of state is 183
# choose action based on epsilon probability
# choose action is right
# (467, 467)
# giving reward -0.0810365 to action right for current state
# Agent previous state: ('forward', {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': 'left'})
# Agent drove right instead of forward. (rewarded -0.08)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# number of state is 183
# choose action based on epsilon probability
# choose action is left
# (468, 468)
# giving reward 1.64425 to action left for current state
# Agent previous state: ('left', {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None})
# Agent followed the waypoint left. (rewarded 1.64)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# Simulation ended. . .
# number of trial runs is 20
# number of states is 183
# number of random actions is 190
# number of actions based on Q-vale is 468

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')
print(len(agent.Q))
# Out:
# 183

# %%
reload(vs)
vs.plot_trials('sim_improved-learning.csv')
print(len(agent.Q))
# Out:
# 384

# %%
reload(vs)
vs.plot_trials('sim_no-learning.csv')
# print(len(agent.Q))

# %%
reload(vs)
vs.plot_trials('sim_improved-learning.csv')
print(len(agent.Q))
# Out:
# 186

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')
print(len(agent.Q))
# Out:
# 179

# %%
agent.current_trial
# Out:
# 20

# %%
agent.epsilon
# Out:
# 0

# %%
w='left'
i={'light':'red', 'oncoming': 'left', 'right': 'left', 'left':None}
s=(w,i)

# %%
s1=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
s2=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
s3=('left', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'forward'})

# %%
q={}
q[str(s1)]={}
q[str(s1)]['left']=0
q[str(s1)]['right']=0
q[str(s1)]['forward']=0
q[str(s1)]['None']=1
# q[]

# %%
max(q[str(s1)].iteritems(), key=operator.itemgetter(1))[0]
# Out:
# 'None'
